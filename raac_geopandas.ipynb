# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import folium

df = pd.read_csv("raac_data.csv")

geolocator = Nominatim(user_agent="uk_schools_locator")
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

def geocode_address(address):
    try:
        location = geocode(f"{address}, UK")
        print(f"Geocoding successful for: {address}")  # Debug print
        return location.latitude, location.longitude
    except:
        print(f"Geocoding failed for: {address}")  # Debug print
        return None, None

# Apply geocoding
df[['latitude', 'longitude']] = df.apply(lambda row: geocode_address(row['Setting Name']), axis=1, result_type='expand')

# Drop rows where location wasn't found
df.dropna(subset=['latitude', 'longitude'], inplace=True)

# Print total number of rows that can be plotted
print(f"Total number of schools plotted on the map: {df.shape[0]}")
# Out:
#                                   Setting Name Publication Group  \
# 0     Atherton St George's CofE Primary School        16/10/2023
# 1               Bushey and Oxhey Infant School        16/10/2023
# 2  Camborne College (part of Cornwall College)        16/10/2023
# 3                     Cann Hall Primary School        16/10/2023
# 4                  Cheddington Combined School        16/10/2023
#
#         Setting Mitigation (16/10/2023) Setting Mitigation (14/09/2023) [1]  \
# 0  All pupils in face-to-face education                                 NaN
# 1  All pupils in face-to-face education                                 NaN
# 2  All pupils in face-to-face education                                 NaN
# 3  All pupils in face-to-face education                                 NaN
# 4  All pupils in face-to-face education                                 NaN
#
#   Setting Mitigation (30/08/2023) Setting Phase      Type of Setting  \
# 0                             NaN       Primary    Academy converter
# 1                             NaN       Primary     Community school
# 2                             NaN       16 plus    Further education
# 3                             NaN       Primary  Academy sponsor led
# 4                             NaN       Primary     Community school
#
#                       Setting Website     URN  LAESTAB  Local Authority  \
# 0      www.saintgeorges.wigan.sch.uk/  144371  3593429            Wigan
# 1      http://www.oxhey.herts.sch.uk/  117157  9192117    Hertfordshire
# 2           http://www.cornwall.ac.uk  130627  9088000         Cornwall
# 3  https://www.cannhall.compassps.uk/  138911  8812025            Essex
# 4           www.cheddingtonschool.org  110215  8252019  Buckinghamshire
#
#   Parliamentary Constituency           Region
# 0                Bolton West       North West
# 1                    Watford  East of England
# 2         Camborne & Redruth       South West
# 3                    Clacton  East of England
# 4                 Buckingham       South East
# Geocoding successful for: Atherton St George's CofE Primary School
# Geocoding successful for: Bushey and Oxhey Infant School
# Geocoding successful for: Camborne College (part of Cornwall College)
# Geocoding failed for: Camborne College (part of Cornwall College)
# Geocoding successful for: Cann Hall Primary School
# Geocoding successful for: Cheddington Combined School
# Geocoding successful for: Christ Church Church of England Academy
# Geocoding successful for: Churchfield CofE Academy
# Geocoding successful for: Crossflatts Primary School
# Geocoding successful for: Dean Trust Rose Bridge
# Geocoding successful for: Dixons Broadgreen Academy
# Geocoding successful for: Ellesmere Port Catholic High School, a Voluntary Academy
# Geocoding failed for: Ellesmere Port Catholic High School, a Voluntary Academy
# Geocoding successful for: Elm Hall Primary School
# Geocoding successful for: Exmouth Community College
# Geocoding successful for: Golden Flatts Primary School
# Geocoding successful for: Gordano School
# Geocoding successful for: Greenway Junior School
# Geocoding successful for: Havant Academy
# Geocoding successful for: Kings College Guildford
# Geocoding successful for: Knuzden St Oswald's Church of England Primary Academy
# Geocoding successful for: Links Academy
# Geocoding successful for: Manningtree High School
# Geocoding successful for: Newmarket Academy
# Geocoding successful for: Peterborough College (part of Inspire Education Group)
# Geocoding failed for: Peterborough College (part of Inspire Education Group)
# Geocoding successful for: Priory Primary School, Bicknacre
# Geocoding successful for: Shelley College, A Share Academy
# Geocoding failed for: Shelley College, A Share Academy
# Geocoding successful for: Shoeburyness High School
# Geocoding successful for: Sir William Borlase's Grammar School
# Geocoding successful for: Southview School
# Geocoding successful for: Spring Meadow Primary School & School House Nursery
# Geocoding successful for: St Aloysius RC College
# Geocoding failed for: St Aloysius RC College
# Geocoding successful for: St Anne's Catholic Primary School
# Geocoding successful for: St Bernard's RC Primary School, Bolton
# Geocoding successful for: St Edward's Catholic Academy
# Geocoding successful for: St Mary Magdalene CofE Primary School
# Geocoding successful for: St Mary's Priory RC Infant School
# Geocoding failed for: St Mary's Priory RC Infant School
# Geocoding successful for: St Stephen and All Martyrs' CofE School, Lever Bridge
# Geocoding failed for: St Stephen and All Martyrs' CofE School, Lever Bridge
# Geocoding successful for: Stowupland High School
# Geocoding successful for: Thameside Primary School
# Geocoding successful for: The Grove Primary Academy
# Geocoding successful for: The Magna Carta School
# Geocoding successful for: Watford Grammar School for Boys
# Geocoding successful for: Westside School
# Geocoding successful for: Winchmore School
# Geocoding successful for: Ark John Keats Academy
# Geocoding successful for: Avenue Centre for Education
# Geocoding failed for: Avenue Centre for Education
# Geocoding successful for: Baildon Church of England Primary School
# Geocoding successful for: Baskerville School
# Geocoding successful for: Buttsbury Junior School
# Geocoding successful for: Colyton Grammar School
# Geocoding successful for: Eldwick Primary School
# Geocoding successful for: Farlingaye High School
# Geocoding successful for: Farnborough College of Technology
# Geocoding successful for: Grantham College
# Geocoding successful for: Kingsbury High School
# Geocoding successful for: Marling School
# Geocoding successful for: Marple Sixth Form College (part of Trafford College Group)
# Geocoding failed for: Marple Sixth Form College (part of Trafford College Group)
# Geocoding successful for: Maryvale Catholic Primary School
# Geocoding successful for: Merrylands Primary School
# Geocoding failed for: Merrylands Primary School
# Geocoding successful for: Mulberry Stepney Green Mathematics and Computing College
# Geocoding successful for: Myton School
# Geocoding successful for: Ortu Corringham Primary School and Nursery
# Geocoding successful for: Ravens Academy
# Geocoding successful for: Selworthy Special School
# Geocoding successful for: St Joseph's Catholic Voluntary Academy
# Geocoding successful for: Steeple Bumpstead Primary School
# Geocoding successful for: Stepney All Saints Church of England Secondary School
# Geocoding successful for: Surrey Street Primary School
# Geocoding successful for: The Link School
# Geocoding successful for: The Macclesfield Academy
# Geocoding successful for: Westlands School
# Geocoding successful for: Abbey Lane Primary School
# Geocoding successful for: All Saints C of E Primary School
# Geocoding successful for: Altrincham College
# Geocoding successful for: Anglo European School
# Geocoding successful for: Ark Boulton Academy
# Geocoding successful for: Arthur Bugler Primary School
# Geocoding successful for: Aston Manor Academy
# Geocoding successful for: Barnes Farm Junior School
# Geocoding failed for: Barnes Farm Junior School
# Geocoding successful for: Batley Girls High School
# Geocoding successful for: Baynards Primary School
# Geocoding successful for: Beehive Lane Community Primary School
# Geocoding successful for: Bentfield Primary School and Nursery
# Geocoding successful for: Birchington Church of England Primary School
# Geocoding successful for: Bishop Douglass School Finchley
# Geocoding successful for: Bispham Endowed Church of England Primary School
# Geocoding successful for: Brandhall Primary School
# Geocoding successful for: Broomfield Primary School
# Geocoding successful for: Buckhurst Hill Community Primary School
# Geocoding successful for: Canon Slade School
# Geocoding successful for: Carmel College
# Geocoding successful for: Cherry Tree Academy
# Geocoding successful for: Chipping Ongar Primary School
# Geocoding successful for: Clacton County High School
# Geocoding successful for: Claydon High School
# Geocoding successful for: Cleeve Park School
# Geocoding successful for: Cockermouth School
# Geocoding successful for: Corpus Christi Catholic Primary School
# Geocoding successful for: Cranbourne
# Geocoding successful for: Danetree Primary School
# Geocoding successful for: Denbigh School
# Geocoding successful for: Donnington Wood Infant School and Nursery Centre
# Geocoding successful for: East Bergholt High School
# Geocoding successful for: East Tilbury Primary School
# Geocoding successful for: Elmstead Primary School
# Geocoding successful for: Eversley Primary School
# Geocoding successful for: Ferryhill School
# Geocoding successful for: Godinton Primary School
# Geocoding successful for: Great Leighs Primary School
# Geocoding successful for: Great Tey Church of England Voluntary Controlled Primary School
# Geocoding successful for: Hadleigh High School
# Geocoding successful for: Harlowbury Primary School
# Geocoding successful for: Harwich and Dovercourt High School
# Geocoding successful for: Hatfield Heath Primary School
# Geocoding successful for: Hatfield Peverel St Andrew's Junior School
# Geocoding failed for: Hatfield Peverel St Andrew's Junior School
# Geocoding successful for: Henham and Ugley Primary and Nursery School
# Geocoding successful for: Hillhouse CofE Primary School
# Geocoding successful for: Hockley Primary School
# Geocoding successful for: Holcombe Grammar School
# Geocoding successful for: Holy Trinity Catholic Voluntary Academy
# Geocoding successful for: Holy Trinity CofE Primary School, Eight Ash Green and Aldham
# Geocoding failed for: Holy Trinity CofE Primary School, Eight Ash Green and Aldham
# Geocoding successful for: Hornsey School for Girls
# Geocoding successful for: Hounsdown School
# Geocoding successful for: Jerounds Primary Academy
# Geocoding successful for: Joyce Frankland Academy, Newport
# Geocoding successful for: Katherine Semar Infant School
# Geocoding successful for: Katherine Semar Junior School
# Geocoding successful for: Katherines Primary Academy and Nursery
# Geocoding successful for: King Ethelbert School
# Geocoding successful for: Kingsdown School
# Geocoding successful for: Lambourne Primary School
# Geocoding successful for: Langney Primary Academy
# Geocoding successful for: Lubbins Park Primary Academy
# Geocoding successful for: Markyate Village School and Nursery
# Geocoding successful for: Mayflower Primary School
# Geocoding successful for: Mersea Island School
# Geocoding successful for: Mistley Norman Church of England Primary School
# Geocoding successful for: Myatt Garden Primary School
# Geocoding successful for: Northampton International Academy
# Geocoding successful for: Our Lady's Catholic High School
# Geocoding successful for: Outwoods Primary School
# Geocoding successful for: Palmarsh Primary School
# Geocoding successful for: Park View School
# Geocoding successful for: Parks Primary School
# Geocoding successful for: Petroc
# Geocoding successful for: Pippins School
# Geocoding successful for: Prince Albert Junior and Infant School
# Geocoding successful for: Redhill School
# Geocoding successful for: Roding Valley High School
# Geocoding successful for: Royal College Manchester (Seashell Trust)
# Geocoding failed for: Royal College Manchester (Seashell Trust)
# Geocoding successful for: Sale Grammar School
# Geocoding successful for: Sandbach School
# Geocoding successful for: Scalby School
# Geocoding successful for: Seven Mills Primary School
# Geocoding successful for: Shawfield Primary School
# Geocoding successful for: Sir Thomas Boughey Academy
# Geocoding successful for: Springfield Primary School
# Geocoding successful for: St Andrew's CofE Primary School, Over Hulton
# Geocoding successful for: St Anne's Catholic Primary School, Harlow Green
# Geocoding successful for: St Bartholomew's Catholic Primary School, Swanley
# Geocoding successful for: St Bede's Catholic School and Byron Sixth Form College
# Geocoding successful for: St Benet's Catholic Primary School, Ouston
# Geocoding successful for: St Clere's School
# Geocoding successful for: St Columba's Catholic Primary School, Wallsend
# Geocoding successful for: St Elizabeth's Catholic Voluntary Academy
# Geocoding successful for: St Francis' Catholic Primary School
# Geocoding successful for: St Francis Catholic Primary School, South Ascot
# Geocoding successful for: St Gregory's Catholic Science College
# Geocoding successful for: St Helena School
# Geocoding successful for: St Ignatius College
# Geocoding successful for: St James' Catholic Primary School, Hebburn
# Geocoding successful for: St James' Church of England Voluntary Aided Primary School
# Geocoding successful for: St John Bosco Catholic Primary School, Town End Farm, Sunderland
# Geocoding successful for: St John Catholic Primary School
# Geocoding successful for: St John Vianney Catholic Primary School, West Denton
# Geocoding failed for: St John Vianney Catholic Primary School, West Denton
# Geocoding successful for: St John Vianney RC Primary School
# Geocoding successful for: St Joseph's Catholic Primary School
# Geocoding successful for: St Lawrence Church of England Primary School, Rowhedge
# Geocoding successful for: St Leonard's Catholic School, Durham
# Geocoding successful for: St Mary and St John Junior and Infant School
# Geocoding successful for: St Michael's Catholic School
# Geocoding successful for: St Paul's Catholic Primary School, Thames Ditton
# Geocoding failed for: St Paul's Catholic Primary School, Thames Ditton
# Geocoding successful for: St Teresa's Catholic Primary School
# Geocoding successful for: St Thomas More Catholic Comprehensive School
# Geocoding successful for: St Thomas More Catholic School, Blaydon
# Geocoding successful for: St William of York Catholic Primary School
# Geocoding successful for: Stanway Fiveways Primary School
# Geocoding successful for: Sunny Bank Primary School
# Geocoding successful for: Tendring Technology College
# Geocoding successful for: The Appleton School
# Geocoding successful for: The Billericay School
# Geocoding successful for: The Bromfords School
# Geocoding successful for: The Coopers' Company and Coborn School
# Geocoding failed for: The Coopers' Company and Coborn School
# Geocoding successful for: The Ellen Wilkinson School for Girls
# Geocoding successful for: The FitzWimarc School
# Geocoding successful for: The Gilberd School
# Geocoding successful for: The Holy Family Catholic School, a Voluntary Academy
# Geocoding failed for: The Holy Family Catholic School, a Voluntary Academy
# Geocoding successful for: The Honywood Community Science School
# Geocoding successful for: The London Oratory School
# Geocoding successful for: The Palmer Catholic Academy
# Geocoding successful for: The Ramsey Academy, Halstead
# Geocoding successful for: The Thomas Lord Audley School
# Geocoding successful for: Thomas Bullock Church of England Primary and Nursery Academy
# Geocoding successful for: Thurstable School Sports College and Sixth Form Centre
# Geocoding successful for: Thurston Community College
# Geocoding successful for: Waddesdon Church of England School
# Geocoding failed for: Waddesdon Church of England School
# Geocoding successful for: Wallingford School
# Geocoding successful for: Water Lane Primary Academy
# Geocoding successful for: Welbourne Primary School
# Geocoding successful for: Wells Park School
# Geocoding successful for: White Court School
# Geocoding successful for: White Hall Academy and Nursery
# Geocoding successful for: Widford School
# Geocoding successful for: Winter Gardens Academy
# Geocoding successful for: Wood Green Academy
# Geocoding successful for: Woodkirk Academy
# Geocoding successful for: Woodville Primary School
# Geocoding successful for: Wyburns Primary School
# Total number of schools plotted on the map: 198

# %%
# Create a map object
map = folium.Map(location=[51.509865, -0.118092], zoom_start=6)

legend_html = '''
<div style="position: fixed; 
     top: 50px; right: 50px; width: 400px; height: 150px; 
     background-color: white; padding: 10px; 
     border:2px solid grey; z-index:9999; font-size:14px; overflow: auto;">
     &nbsp; <b>Color Code Legend</b> <br>
     &nbsp; Green: RAAC not present &nbsp; <i class="fa fa-map-marker fa-2x" style="color:green"></i><br>
     &nbsp; Red: Mix of face-to-face and remote arrangements &nbsp; <i class="fa fa-map-marker fa-2x" style="color:red"></i><br>
     &nbsp; Purple: All pupils in face-to-face education &nbsp; <i class="fa fa-map-marker fa-2x" style="color:purple"></i><br>
</div>
'''

# Apply the color determination function within the loop that creates markers
def determine_pin_color(row):
    # Check if "RAAC not present" is in the "Setting Mitigation (16/10/2023)" field or any other mitigation fields
    if row['Setting Mitigation (16/10/2023)'] == 'RAAC not present' or \
       row['Setting Mitigation (14/09/2023) [1]'] == 'RAAC not present' or \
       row['Setting Mitigation (30/08/2023)'] == 'RAAC not present':
        return 'green'
    # Check if "Mix of face-to-face and remote arrangements" is in the "Setting Mitigation (16/10/2023)" field
    elif row['Setting Mitigation (16/10/2023)'] == 'Mix of face-to-face and remote arrangements':
        return 'red'
    # Check if "All pupils in face-to-face education" is in the "Setting Mitigation (16/10/2023)" field
    elif row['Setting Mitigation (16/10/2023)'] == 'All pupils in face-to-face education':
        return 'purple'
    else:
        return 'blue'  # Default color

# Apply the color determination function within the loop that creates markers
for index, row in df.iterrows():
    # Construct the popup message with additional information
    popup_info = folium.Popup(
        (
            f"<strong>Setting Name:</strong> {row['Setting Name']}<br>"
            f"<strong>Setting Phase:</strong> {row['Setting Phase']}<br>"
            f"<strong>Type of Setting:</strong> {row['Type of Setting']}<br>"
            f"<strong>Setting Website:</strong> {row['Setting Website']}<br>"
            f"<strong>Local Authority:</strong> {row['Local Authority']}<br>"
            f"<strong>Parliamentary Constituency:</strong> {row['Parliamentary Constituency']}<br>"
            f"<strong>Region:</strong> {row['Region']}<br>"
            f"<strong>URN:</strong> {row['URN']}<br>"
            f"<strong>LAESTAB:</strong> {row['LAESTAB']}<br>"           
            f"<strong>Mitigation (30/08/2023):</strong> {row['Setting Mitigation (30/08/2023)']}<br>"
            f"<strong>Mitigation (14/09/2023):</strong> {row['Setting Mitigation (14/09/2023) [1]']}<br>"
            f"<strong>Mitigation (16/10/2023):</strong> {row['Setting Mitigation (16/10/2023)']}<br>"
        ),
        max_width=350
    )
    
    # Determine the color of the pin based on the mitigation status
    pin_color = determine_pin_color(row)
    
    # Add a marker to the map
    folium.Marker(
        [row['latitude'], row['longitude']],
        popup=popup_info,
        icon=folium.Icon(color=pin_color)  # This sets the color of the pin based on the mitigation status
    ).add_to(map)

# Add the legend to the map
map.get_root().html.add_child(folium.Element(legend_html))
# Display the map
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91d35bc27c09a3acdf58a4bcab1a4cff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
# &lt;div style=&quot;position: fixed;
#      top: 50px; right: 50px; width: 400px; height: 150px;
#      background-color: white; padding: 10px;
#      border:2px solid grey; z-index:9999; font-size:14px; overflow: auto;&quot;&gt;
#      &amp;nbsp; &lt;b&gt;Color Code Legend&lt;/b&gt; &lt;br&gt;
#      &amp;nbsp; Green: RAAC not present &amp;nbsp; &lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:green&quot;&gt;&lt;/i&gt;&lt;br&gt;
#      &amp;nbsp; Red: Mix of face-to-face and remote arrangements &amp;nbsp; &lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&lt;br&gt;
#      &amp;nbsp; Purple: All pupils in face-to-face education &amp;nbsp; &lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:purple&quot;&gt;&lt;/i&gt;&lt;br&gt;
# &lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91d35bc27c09a3acdf58a4bcab1a4cff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91d35bc27c09a3acdf58a4bcab1a4cff = L.map(
#                 &quot;map_91d35bc27c09a3acdf58a4bcab1a4cff&quot;,
#                 {
#                     center: [51.509865, -0.118092],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f3d060ad0a4bab4d9f036daffaabde7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_6f3d060ad0a4bab4d9f036daffaabde7.addTo(map_91d35bc27c09a3acdf58a4bcab1a4cff);
#
#             var marker_a420bfaf549d3efb18f0f46a198877e7 = L.marker(
#                 [53.528717650000004, -2.4993370176265453],
#                 {}
#             ).addTo(map_91d35bc27c09a3acdf58a4bcab1a4cff);
#
#
#             var icon_6845496491944ee6d3ddf1ee55252f27 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a420bfaf549d3efb18f0f46a198877e7.setIcon(icon_6845496491944ee6d3ddf1ee55252f27);
#
#
#         var popup_c060cd5df4ee17672124e503ac4d5d2e = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var html_d6080ceeed314a2915008e83cf66c7df = $(`&lt;div id=&quot;html_d6080ceeed314a2915008e83cf66c7df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Setting Name:&lt;/strong&gt; Atherton St George&#x27;s CofE Primary School&lt;br&gt;&lt;strong&gt;Setting Phase:&lt;/strong&gt; Primary&lt;br&gt;&lt;strong&gt;Type of Setting:&lt;/strong&gt; Academy converter&lt;br&gt;&lt;strong&gt;Setting Website:&lt;/strong&gt; www.saintgeorges.wigan.sch.uk/&lt;br&gt;&lt;strong&gt;Local Authority:&lt;/strong&gt; Wigan&lt;br&gt;&lt;strong&gt;Parliamentary Constituency:&lt;/strong&gt; Bolton West&lt;br&gt;&lt;strong&gt;Region:&lt;/strong&gt; North West&lt;br&gt;&lt;strong&gt;URN:&lt;/strong&gt; 144371&lt;br&gt;&lt;strong&gt;LAESTAB:&lt;/strong&gt; 3593429&lt;br&gt;&lt;strong&gt;Mitigation (30/08/2023):&lt;/strong&gt; nan&lt;br&gt;&lt;strong&gt;Mitigation (14/09/2023):&lt;/strong&gt; nan&lt;br&gt;&lt;strong&gt;Mitigation (16/10/2023):&lt;/strong&gt; All pupils in face-to-face education&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_c060cd5df4ee17672124e503ac4d5d2e.setContent(html_d6080ceeed314a2915008e83cf66c7df);
#
#
#
#         marker_a420bfaf549d3efb18f0f46a198877e7.bindPopup(popup_c060cd5df4ee17672124e503ac4d5d2e)
#         ;
#
#
#
#
#             var marker_491c768025a13070e13b2345ffffc644 = L.marker(
#                 [51.647446, -0.38016106491546003],
#                 {}
#             ).addTo(map_91d35bc27c09a3acdf58a4bcab1a4cff);
#
#
#             var icon_88c568bc1e7bf7e254884c526145aa85 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_491c768025a13070e13b2345ffffc644.setIcon(icon_88c568bc1e7bf7e254884c526145aa85);
#
#
#         var popup_48ec217da6a4704d1d74a82cf113c5fe = L.popup({&quot;maxWidth&quot;: 350});
#
#
#
#                 var html_3dd09a0e80420f59345c7d528dd6ecbd = $(`&lt;div id=&quot;html_3dd09a0e80420f59345c7d528dd6ecbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;strong&gt;Setting Name:&lt;/strong&gt; Bushey and Oxhey Infant School&lt;br&gt;&lt;strong&gt;Setting Phase:&lt;/strong&gt; Primary&lt;br&gt;&lt;strong&gt;Type of Setting:&lt
